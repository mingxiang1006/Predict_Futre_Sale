# %% [markdown]
# # Predicting Future Sales
# ## Data Exploration and Cleaning Note Book

# %% [markdown]
# **Table of contents**
# <br>Notebook Setup
# 1. Exploration and Cleaning<br>
#     1.1 Check Characteristic values<br>
#     1.2 Check Key Figure values<br>
# 2. Exploratory Analysis<br>
#     2.1 Sales General Trend - Heat Map<br>
#     2.2 Items<br>
#     2.3 Shop<br>
#     2.4 Category<br>

# %% [markdown]
# ## Notebook setup

# %%
import pandas as pd
import matplotlib.pyplot as plt # basic plotting
import seaborn as sns # for prettier plots
import numpy as np
import calmap
import math
import calmap

# %% [markdown]
# ### Data Manipulation Options
#
# You may change the value below to remove or keep the data as is <br>
# REMOVE_NEGATIVE_COUNTS: Remove Negative item_cnt_day <br>
# REMOVE_NONREV_PRODUCT: Remove product that is not relevant to prediction <br>
# REMOVE_NON_PREDICT_ITM: Remove the item(s) that is not required for prediction <br>
#
# Please note that changing these parameter will impact the some of the
# result below because some data set is removed after changing the value

# %%
REMOVE_NEGATIVE_COUNTS = True
REMOVE_NEGATIVE_PRICE = True
REMOVE_NON_PREDICT_ITM = True

# %% [markdown]
# ## 1. Exploration and Cleaning

# %%
sales = pd.read_csv("sales_train.csv")
items = pd.read_csv("items.csv")
categories = pd.read_csv("item_categories.csv")
shops = pd.read_csv("shops.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# ### 1.1 Check Characteristic values

# %% [markdown]
# **1.1.1 Sales**

# %%
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %% [markdown]
# Check for null value

# %%
sales.isna().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %% [markdown]
# <br>
# From first 5 rows, we can already infer that there is data quality issue:
#
# There is a negative value showing in the itm_cnt_day field.
#
# Let's remove the negative value if required (can be configure at the Data
# Manipulation Options section above)
# <br>

# %%
if REMOVE_NEGATIVE_COUNTS:
    sales = sales[sales.item_cnt_day >= 0]
if REMOVE_NEGATIVE_PRICE:
    sales = sales[sales.item_price >= 0]
if REMOVE_NON_PREDICT_ITM: 
    testUniID = list(test.item_id.unique())

    for idx in items.index:
        id = items.loc[idx, "item_id"]
        items.loc[idx, "Required"] = id in testUniID
# pre merge to removed data that are not related for prediction
# will drop the "Required" column for cleaner data. 
    sales = sales.merge(items, how="left", on="item_id")
    
    sales = sales[sales.Required == True]
    
# Drop column for cleaner data
    sales = sales.iloc[:, 0:6]

print()    
print("Total Number of rows for sales data frame: {}".format(len(sales))) 
print()
sales.head()
# Out:
# Total Number of rows for sales data frame: 1442564
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0 2013-02-01               0       59    22154       999.0           1.0
# 1 2013-03-01               0       25     2574       399.0           2.0
# 2 2013-05-01               0       25     2574       399.0           1.0
# 3 2013-07-01               0       25     2574       399.0           1.0
# 4 2013-08-01               0       25     2574       399.0           2.0

# %% [markdown]
# As shown in the data frame data above, we definately have duplicate data that are required for prediction.
#
# **NB! We will need to think about how to solve it**

# %% [markdown]
# Let's check whether sales have duplicate data

# %%
print("number of duplicates : {}".format(
    sales.duplicated(subset=["date", "shop_id", "item_id"]).sum()))

checksales = sales[sales.duplicated(subset=["date", "shop_id", 
                                            "item_id"], keep=False)].copy()

checksales.sort_values(by = ["item_id","shop_id"])
# Out:
# number of duplicates : 11
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 1492994 2014-03-23              14       21     3423      999.00           1.0
# 1492995 2014-03-23              14       21     3423      999.00           1.0
# 1861693 2014-12-07              18       25     3423      999.00           1.0
# 1861711 2014-12-07              18       25     3423      999.00           1.0
# 1431756 2014-02-23              13       50     3423      999.00           1.0
# 1431758 2014-02-23              13       50     3423      999.00           1.0
# 1667711 2014-01-05              16       50     3423      999.00           1.0
# 1667712 2014-01-05              16       50     3423      999.00           1.0
# 2266491 2014-12-26              23       17     3424      999.00           2.0
# 2266492 2014-12-26              23       17     3424     1199.00           1.0
# 2226136 2014-12-22              23       31     8237       99.00           1.0
# 2226140 2014-12-22              23       31     8237      149.00           1.0
# 2208378 2014-12-31              23       57     8237       99.00           1.0
# 2208379 2014-12-31              23       57     8237      149.00           1.0
# 142262  2013-02-18               1       16    15702      149.00           1.0
# 142263  2013-02-18               1       16    15702      549.00           1.0
# 2902070 2015-07-10              33       12    21619      399.00           1.0
# 2902071 2015-07-10              33       12    21619      499.00           1.0
# 2193118 2014-12-31              23       42    21619      499.00           1.0
# 2193120 2014-12-31              23       42    21619      499.00           1.0
# 2414471 2015-12-02              25       42    21619      465.05           1.0
# 2414472 2015-12-02              25       42    21619      499.00           1.0

# %% [markdown]
# Let's check whether all the duplicate data is required for prediction or not.

# %%
testUniID = list(test.item_id.unique())

for idx in checksales.index:
    id = checksales.loc[idx, "item_id"]
    checksales.loc[idx, "Required"] = id in testUniID

#checksales[checksales.Required == False]
checksales
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 142262  2013-02-18               1       16    15702      149.00
# 142263  2013-02-18               1       16    15702      549.00
# 1431756 2014-02-23              13       50     3423      999.00
# 1431758 2014-02-23              13       50     3423      999.00
# 1492994 2014-03-23              14       21     3423      999.00
# 1492995 2014-03-23              14       21     3423      999.00
# 1667711 2014-01-05              16       50     3423      999.00
# 1667712 2014-01-05              16       50     3423      999.00
# 1861693 2014-12-07              18       25     3423      999.00
# 1861711 2014-12-07              18       25     3423      999.00
# 2193118 2014-12-31              23       42    21619      499.00
# 2193120 2014-12-31              23       42    21619      499.00
# 2208378 2014-12-31              23       57     8237       99.00
# 2208379 2014-12-31              23       57     8237      149.00
# 2226136 2014-12-22              23       31     8237       99.00
# 2226140 2014-12-22              23       31     8237      149.00
# 2266491 2014-12-26              23       17     3424      999.00
# 2266492 2014-12-26              23       17     3424     1199.00
# 2414471 2015-12-02              25       42    21619      465.05
# 2414472 2015-12-02              25       42    21619      499.00
# 2902070 2015-07-10              33       12    21619      399.00
# 2902071 2015-07-10              33       12    21619      499.00
#
#          item_cnt_day Required
# 142262            1.0     True
# 142263            1.0     True
# 1431756           1.0     True
# 1431758           1.0     True
# 1492994           1.0     True
# 1492995           1.0     True
# 1667711           1.0     True
# 1667712           1.0     True
# 1861693           1.0     True
# 1861711           1.0     True
# 2193118           1.0     True
# 2193120           1.0     True
# 2208378           1.0     True
# 2208379           1.0     True
# 2226136           1.0     True
# 2226140           1.0     True
# 2266491           2.0     True
# 2266492           1.0     True
# 2414471           1.0     True
# 2414472           1.0     True
# 2902070           1.0     True
# 2902071           1.0     True

# %% [markdown]
# Let's check on the date format

# %%
sales.date.describe()
# Out:
# count        2935849
# unique          1034
# top       28.12.2013
# freq            9434
# Name: date, dtype: object

# %% [markdown]
# Let's convert the date to correct format

# %%
sales['date'] = pd.to_datetime(sales['date'])

sales.date.describe()
# Out:
# count                 1442564
# unique                   1034
# top       2014-12-30 00:00:00
# freq                     6796
# first     2013-01-01 00:00:00
# last      2015-12-10 00:00:00
# Name: date, dtype: object

# %% [markdown]
# The data is now in time stamp format

# %% [markdown]
# **1.1.2 Items**

# %%
print()
print("Total Number of rows for items data frame: {}".format(len(items)))
print()
items.head()
# Out:
# Total Number of rows for items data frame: 22170
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id Required
# 0                40    False
# 1                76    False
# 2                40    False
# 3                40    False
# 4                40    False

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %% [markdown]
# Let's check on the item_name for Russian Name. The item_name duplication will also
# exclude item_name that are duplicate but different category.

# %%
checkitems = items[items.duplicated(
    subset=["item_name", "item_category_id"], keep=False)].copy()

checkitems
# Out:
# Empty DataFrame
# Columns: [item_name, item_id, item_category_id]
# Index: []

# %% [markdown]
# No duplication found for Russian item_name

# %% [markdown]
# **NB! Do we want to have English name as well. Based on the example, it seems that english name will have a lot of overlapping.**
#
# **Check overlapping and maybe ignore case that is not relevant to the result i.e. don't need to predict.**

# %% [markdown]
# **1.1.3 Categories**

# %%
print()
print("Total Number of rows for categories data frame: {}".format(len(categories))) 
print()
categories.head()
# Out:
# Total Number of rows for categories data frame: 84
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# Let's check duplicates on the categories name

# %%
print("number of duplicates : {}".format(
    categories.duplicated(subset=["item_category_name"]).sum()))
# Out:
# number of duplicates : 0

# %% [markdown]
# **NB! Do we want to have English name as well. Based on the example, it seems that english name will have a lot of overlapping.**
#
# **Check overlapping and maybe ignore case that is not relevant to the result i.e. don't need to predict.**

# %% [markdown]
# **1.1.4 Shops**

# %%
print()
print("Number of rows for sales data frame : {:,.0f}".format(len(shops)))
shops.head()
# Out:
# Number of rows for sales data frame : 60
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# <br>
# Let's check duplicaton for shops
# <br><br>

# %%
print("number of duplicates : {}".format(shops.duplicated().sum()))
# Out:
# number of duplicates : 0

# %% [markdown]
# ### 1.2 Check Key Figure values

# %% [markdown]
# **1.2.1 Normalise all data for further analysis**

# %%
normData = sales.merge(shops, how="left", on="shop_id")
normData = normData.merge(items, how="left", on="item_id")
normData = normData.merge(categories, how="left", on="item_category_id")
normData.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154       999.0           1.0
# 1 2013-03-01               0       25     2574       399.0           2.0
# 2 2013-05-01               0       25     2574       399.0           1.0
# 3 2013-07-01               0       25     2574       399.0           1.0
# 4 2013-08-01               0       25     2574       399.0           2.0
#
#                 shop_name                                          item_name  \
# 0  Ярославль ТЦ "Альтаир"                                  ЯВЛЕНИЕ 2012 (BD)
# 1     Москва ТРК "Атриум"  DEL REY LANA  Born To Die  The Paradise Editio...
# 2     Москва ТРК "Атриум"  DEL REY LANA  Born To Die  The Paradise Editio...
# 3     Москва ТРК "Атриум"  DEL REY LANA  Born To Die  The Paradise Editio...
# 4     Москва ТРК "Атриум"  DEL REY LANA  Born To Die  The Paradise Editio...
#
#    item_category_id Required                   item_category_name
# 0                37     True                       Кино - Blu-Ray
# 1                55     True  Музыка - CD локального производства
# 2                55     True  Музыка - CD локального производства
# 3                55     True  Музыка - CD локального производства
# 4                55     True  Музыка - CD локального производства

# %%
normData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2935849 entries, 0 to 2935848
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                datetime64[ns]
#  1   date_block_num      int64
#  2   shop_id             int64
#  3   item_id             int64
#  4   item_price          float64
#  5   item_cnt_day        float64
#  6   shop_name           object
#  7   item_name           object
#  8   item_category_id    int64
#  9   item_category_name  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 246.4+ MB

# %% [markdown]
# Check for null value

# %%
# Check whether there is null value or not
normData.isna().sum()
# Out:
# date                  0
# date_block_num        0
# shop_id               0
# item_id               0
# item_price            0
# item_cnt_day          0
# shop_name             0
# item_name             0
# item_category_id      0
# item_category_name    0
# dtype: int64

# %% [markdown]
# **1.2.2 Check Key Figure Values**

# %% [markdown]
# Let's have a general look on all the key figure.

# %%
normData.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    1.442564e+06  1.442564e+06  1.442564e+06  1.442564e+06  1.442564e+06
# mean     1.879477e+01  3.279293e+01  9.650329e+03  1.020788e+03  1.335614e+00
# std      9.083670e+00  1.616813e+01  6.305674e+03  1.805546e+03  3.191628e+00
# min      0.000000e+00  0.000000e+00  3.000000e+01  5.000000e-01  1.000000e+00
# 25%      1.200000e+01  2.200000e+01  4.181000e+03  2.990000e+02  1.000000e+00
# 50%      2.000000e+01  3.100000e+01  7.856000e+03  5.490000e+02  1.000000e+00
# 75%      2.600000e+01  4.700000e+01  1.525700e+04  1.199000e+03  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216700e+04  5.920000e+04  2.169000e+03
#
#        item_category_id
# count      1.442564e+06
# mean       4.074066e+01
# std        1.863186e+01
# min        2.000000e+00
# 25%        2.800000e+01
# 50%        4.000000e+01
# 75%        5.500000e+01
# max        8.300000e+01

# %% [markdown]
# **1.2.3 Check item_price**

# %% [markdown]
# ****Note: This section will be impacted/will not able to show intended result by setting the remove parameter.**<br>
# **Set all remove parameter to False to correct data**

# %%
normData.item_price.describe()
# Out:
# count    1.442564e+06
# mean     1.020788e+03
# std      1.805546e+03
# min      5.000000e-01
# 25%      2.990000e+02
# 50%      5.490000e+02
# 75%      1.199000e+03
# max      5.920000e+04
# Name: item_price, dtype: float64

# %% [markdown]
# Let's put the item_pricing into a box plot

# %%
fig = plt.figure(figsize=(20, 8))
ax = plt.axes()
fig.suptitle("Item Prices box plot")
sns.boxplot(x=normData.item_price, ax=ax)
plt.show()

# %% [markdown]
# It seems that there is a extreme outlier and let's look further into the extreme outlier.
#
# The sales_price is higher than 300000.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest

model=IsolationForest(n_estimators=100, max_samples='auto', contamination=float(0.1),max_features=1.0)
model.fit(normData[['item_price']])
normData['scores']=model.decision_function(normData[['item_price']])
normData['anomaly']=model.predict(normData[['item_price']])

# %%
normData.groupby('anomaly').count()
#normData.head()
# Out:
#             date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# anomaly
# -1        138792          138792   138792   138792      138792        138792
#  1       1303772         1303772  1303772  1303772     1303772       1303772
#
#          shop_name  item_name  item_category_id  Required  item_category_name  \
# anomaly
# -1          138792     138792            138792    138792              138792
#  1         1303772    1303772           1303772   1303772             1303772
#
#           scores
# anomaly
# -1        138792
#  1       1303772

# %%
normData2 = normData[normData.anomaly != -1]

fig = plt.figure(figsize=(20, 8))
ax = plt.axes()
fig.suptitle("Item Prices box plot")
sns.boxplot(x=normData2.item_price, ax=ax)
plt.show()

# %%
normData[normData.item_price >= 300000]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 1163158 2013-12-13              11       12     6066    307980.0
#
#          item_cnt_day            shop_name             item_name  \
# 1163158           1.0  Интернет-магазин ЧС  Radmin 3  - 522 лиц.
#
#          item_category_id            item_category_name
# 1163158                75  Программы - Для дома и офиса

# %% [markdown]
# Note: the result above will be empty if the remove parameter is set.

# %% [markdown]
# It appears that there is only 1 item for item_price >= 300000. Let's check how many 6066 item_id in the data set.

# %%
print("Number of record with item_id 6066: {}".format(len(normData[normData.item_id == 6066])))
# Out:
# Number of record with item_id 6066: 1

# %% [markdown]
# Only 1 record therefore we can definately delete the outlier.

# %%
normData = normData[normData.item_price < 300000]

# %%
fig = plt.figure(figsize=(20, 8))
ax = plt.axes()
fig.suptitle("Item Prices")
sns.boxplot(x=normData.item_price, ax=ax)
plt.show()

# %% [markdown]
# **NB! Let's check out the data after removing using Amy's code**

# %% [markdown]
# **1.2.4 Check item count**

# %%
normData.item_cnt_day.describe()
# Out:
# count    2.935848e+06
# mean     1.242641e+00
# std      2.618835e+00
# min     -2.200000e+01
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.169000e+03
# Name: item_cnt_day, dtype: float64

# %%
fig = plt.figure(figsize=(20, 8))
ax = plt.axes()
fig.suptitle("Item Count Day")
sns.boxplot(x=normData.item_cnt_day, ax=ax)
plt.show()

# %% [markdown]
# Let's check the outlier

# %%
checkItemCnt = normData[normData.item_cnt_day >= 500]

checkItemCnt
# Out:
#               date  date_block_num  shop_id  item_id   item_price  \
# 1573253 2014-04-22              15       27     8057  1200.000000
# 1708207 2014-06-28              17       25    20949     5.000000
# 2048518 2014-02-10              21       12     9242  1500.000000
# 2067669 2014-09-10              21       55    19437   899.000000
# 2257299 2014-12-19              23       12    20949     4.000000
# 2326930 2015-01-15              24       12    20949     4.000000
# 2608040 2015-04-14              27       12     3731  1904.548077
# 2626181 2015-05-19              28       12    11373   155.192950
# 2851073 2015-09-29              32       55     9249  1500.000000
# 2851091 2015-09-30              32       55     9249  1702.825746
# 2864235 2015-09-30              32       12     9248  1692.526158
# 2864260 2015-09-29              32       12     9248  1500.000000
# 2909401 2015-10-14              33       12    20949     4.000000
# 2909818 2015-10-28              33       12    11373     0.908714
#
#          item_cnt_day                       shop_name  \
# 1573253         502.0  Москва ТЦ "МЕГА Белая Дача II"
# 1708207         501.0             Москва ТРК "Атриум"
# 2048518         512.0             Интернет-магазин ЧС
# 2067669         508.0        Цифровой склад 1С-Онлайн
# 2257299         500.0             Интернет-магазин ЧС
# 2326930        1000.0             Интернет-магазин ЧС
# 2608040         624.0             Интернет-магазин ЧС
# 2626181         539.0             Интернет-магазин ЧС
# 2851073         533.0        Цифровой склад 1С-Онлайн
# 2851091         637.0        Цифровой склад 1С-Онлайн
# 2864235         669.0             Интернет-магазин ЧС
# 2864260         504.0             Интернет-магазин ЧС
# 2909401         500.0             Интернет-магазин ЧС
# 2909818        2169.0             Интернет-магазин ЧС
#
#                                                  item_name  item_category_id  \
# 1573253                                   iTunes 1500 руб.                32
# 1708207  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2048518  Билет "ИгроМир 2014" (на один день (отдельно -...                 8
# 2067669     Средиземье: Тени Мордора [PC, Цифровая версия]                31
# 2257299  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2326930  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2608040          Grand Theft Auto V [PC, русские субтитры]                30
# 2626181               Доставка до пункта выдачи (Boxberry)                 9
# 2851073  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) У...                 8
# 2851091  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) У...                 8
# 2864235  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) [...                80
# 2864260  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) [...                80
# 2909401  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2909818               Доставка до пункта выдачи (Boxberry)                 9
#
#                                item_category_name
# 1573253         Карты оплаты (Кино, Музыка, Игры)
# 1708207  Подарки - Сумки, Альбомы, Коврики д/мыши
# 2048518                            Билеты (Цифра)
# 2067669                           Игры PC - Цифра
# 2257299  Подарки - Сумки, Альбомы, Коврики д/мыши
# 2326930  Подарки - Сумки, Альбомы, Коврики д/мыши
# 2608040             Игры PC - Стандартные издания
# 2626181                           Доставка товара
# 2851073                            Билеты (Цифра)
# 2851091                            Билеты (Цифра)
# 2864235                        Служебные - Билеты
# 2864260                        Служебные - Билеты
# 2909401  Подарки - Сумки, Альбомы, Коврики д/мыши
# 2909818                           Доставка товара

# %%
for idx in checkItemCnt.index:
    id = checkItemCnt.loc[idx, "item_id"]
    checkItemCnt.loc[idx, "Required"] = id in testUniID

checkItemCnt.sort_values(by= "item_id")
    
#checkItemCnt[checkItemCnt.Required == True]
# Out:
# C:\Users\KANGHEA\Anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\KANGHEA\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#               date  date_block_num  shop_id  item_id   item_price  \
# 2608040 2015-04-14              27       12     3731  1904.548077
# 1573253 2014-04-22              15       27     8057  1200.000000
# 2048518 2014-02-10              21       12     9242  1500.000000
# 2864235 2015-09-30              32       12     9248  1692.526158
# 2864260 2015-09-29              32       12     9248  1500.000000
# 2851073 2015-09-29              32       55     9249  1500.000000
# 2851091 2015-09-30              32       55     9249  1702.825746
# 2626181 2015-05-19              28       12    11373   155.192950
# 2909818 2015-10-28              33       12    11373     0.908714
# 2067669 2014-09-10              21       55    19437   899.000000
# 1708207 2014-06-28              17       25    20949     5.000000
# 2257299 2014-12-19              23       12    20949     4.000000
# 2326930 2015-01-15              24       12    20949     4.000000
# 2909401 2015-10-14              33       12    20949     4.000000
#
#          item_cnt_day                       shop_name  \
# 2608040         624.0             Интернет-магазин ЧС
# 1573253         502.0  Москва ТЦ "МЕГА Белая Дача II"
# 2048518         512.0             Интернет-магазин ЧС
# 2864235         669.0             Интернет-магазин ЧС
# 2864260         504.0             Интернет-магазин ЧС
# 2851073         533.0        Цифровой склад 1С-Онлайн
# 2851091         637.0        Цифровой склад 1С-Онлайн
# 2626181         539.0             Интернет-магазин ЧС
# 2909818        2169.0             Интернет-магазин ЧС
# 2067669         508.0        Цифровой склад 1С-Онлайн
# 1708207         501.0             Москва ТРК "Атриум"
# 2257299         500.0             Интернет-магазин ЧС
# 2326930        1000.0             Интернет-магазин ЧС
# 2909401         500.0             Интернет-магазин ЧС
#
#                                                  item_name  item_category_id  \
# 2608040          Grand Theft Auto V [PC, русские субтитры]                30
# 1573253                                   iTunes 1500 руб.                32
# 2048518  Билет "ИгроМир 2014" (на один день (отдельно -...                 8
# 2864235  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) [...                80
# 2864260  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) [...                80
# 2851073  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) У...                 8
# 2851091  Билет "ИгроМир 2015" - 3 октября 2015 (сайт) У...                 8
# 2626181               Доставка до пункта выдачи (Boxberry)                 9
# 2909818               Доставка до пункта выдачи (Boxberry)                 9
# 2067669     Средиземье: Тени Мордора [PC, Цифровая версия]                31
# 1708207  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2257299  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2326930  Фирменный пакет майка 1С Интерес белый (34*42)...                71
# 2909401  Фирменный пакет майка 1С Интерес белый (34*42)...                71
#
#                                item_category_name Required
# 2608040             Игры PC - Стандартные издания     True
# 1573253         Карты оплаты (Кино, Музыка, Игры)    False
# 2048518                            Билеты (Цифра)    False
# 2864235                        Служебные - Билеты    False
# 2864260                        Служебные - Билеты    False
# 2851073                            Билеты (Цифра)    False
# 2851091                            Билеты (Цифра)    False
# 2626181                           Доставка товара     True
# 2909818                           Доставка товара     True
# 2067669                           Игры PC - Цифра    False
# 1708207  Подарки - Сумки, Альбомы, Коврики д/мыши     True
# 2257299  Подарки - Сумки, Альбомы, Коврики д/мыши     True
# 2326930  Подарки - Сумки, Альбомы, Коврики д/мыши     True
# 2909401  Подарки - Сумки, Альбомы, Коврики д/мыши     True

# %% [markdown]
# It appears that some of the item_id do have high item_cnt_day number.
#
# Let's look further into 3731 and 8057 as they only have 1 rows

# %%
checkItemCnt = normData[normData.item_id == 3731]

checkItemCnt.sort_values(by = 'item_cnt_day')
# Out:
#               date  date_block_num  shop_id  item_id   item_price  \
# 2625897 2015-05-28              28       12     3731  1999.000000
# 2904514 2015-10-15              33       53     3731  2199.000000
# 2813516 2015-08-13              31        3     3731  1999.000000
# 2703993 2015-06-18              29        4     3731  1999.000000
# 2728024 2015-04-07              30       16     3731  1999.000000
# ...            ...             ...      ...      ...          ...
# 2605020 2015-04-14              27       18     3731  1930.034483
# 2555809 2015-04-14              27       31     3731  1946.953216
# 2567454 2015-04-14              27       25     3731  1941.995169
# 2597018 2015-04-14              27       42     3731  1918.732441
# 2608040 2015-04-14              27       12     3731  1904.548077
#
#          item_cnt_day                       shop_name  \
# 2625897          -1.0             Интернет-магазин ЧС
# 2904514          -1.0                Уфа ТЦ "Семья" 2
# 2813516          -1.0  Балашиха ТРК "Октябрь-Киномир"
# 2703993          -1.0        Волжский ТЦ "Волга Молл"
# 2728024          -1.0                Коломна ТЦ "Рио"
# ...               ...                             ...
# 2605020         145.0            Красноярск ТЦ "Июнь"
# 2555809         171.0         Москва ТЦ "Семеновский"
# 2567454         207.0             Москва ТРК "Атриум"
# 2597018         299.0          СПб ТК "Невский Центр"
# 2608040         624.0             Интернет-магазин ЧС
#
#                                          item_name  item_category_id  \
# 2625897  Grand Theft Auto V [PC, русские субтитры]                30
# 2904514  Grand Theft Auto V [PC, русские субтитры]                30
# 2813516  Grand Theft Auto V [PC, русские субтитры]                30
# 2703993  Grand Theft Auto V [PC, русские субтитры]                30
# 2728024  Grand Theft Auto V [PC, русские субтитры]                30
# ...                                            ...               ...
# 2605020  Grand Theft Auto V [PC, русские субтитры]                30
# 2555809  Grand Theft Auto V [PC, русские субтитры]                30
# 2567454  Grand Theft Auto V [PC, русские субтитры]                30
# 2597018  Grand Theft Auto V [PC, русские субтитры]                30
# 2608040  Grand Theft Auto V [PC, русские субтитры]                30
#
#                     item_category_name
# 2625897  Игры PC - Стандартные издания
# 2904514  Игры PC - Стандартные издания
# 2813516  Игры PC - Стандартные издания
# 2703993  Игры PC - Стандартные издания
# 2728024  Игры PC - Стандартные издания
# ...                                ...
# 2605020  Игры PC - Стандартные издания
# 2555809  Игры PC - Стандартные издания
# 2567454  Игры PC - Стандартные издания
# 2597018  Игры PC - Стандартные издания
# 2608040  Игры PC - Стандартные издания
#
# [2354 rows x 10 columns]

# %%
checkItemCnt = normData[normData.item_id == 8057]

checkItemCnt.sort_values(by = 'item_cnt_day')
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 807027  2013-08-24               7       28     8057      1500.0
# 1596496 2014-04-28              15       42     8057      1500.0
# 1596497 2014-04-04              15       42     8057      1500.0
# 1599851 2014-04-25              15       44     8057      1500.0
# 1631422 2014-05-24              16       27     8057      1500.0
# ...            ...             ...      ...      ...         ...
# 2043157 2014-01-10              21       27     8057      1500.0
# 1571406 2014-04-23              15       21     8057      1200.0
# 1618930 2014-04-23              15       29     8057      1200.0
# 1573252 2014-04-23              15       27     8057      1200.0
# 1573253 2014-04-22              15       27     8057      1200.0
#
#          item_cnt_day                           shop_name         item_name  \
# 807027            1.0     Москва ТЦ "МЕГА Теплый Стан" II  iTunes 1500 руб.
# 1596496           1.0              СПб ТК "Невский Центр"  iTunes 1500 руб.
# 1596497           1.0              СПб ТК "Невский Центр"  iTunes 1500 руб.
# 1599851           1.0                 Самара ТЦ "Мелодия"  iTunes 1500 руб.
# 1631422           1.0      Москва ТЦ "МЕГА Белая Дача II"  iTunes 1500 руб.
# ...               ...                                 ...               ...
# 2043157          11.0      Москва ТЦ "МЕГА Белая Дача II"  iTunes 1500 руб.
# 1571406         100.0              Москва МТРЦ "Афи Молл"  iTunes 1500 руб.
# 1618930         240.0  Москва ТЦ "Новый век" (Новокосино)  iTunes 1500 руб.
# 1573252         401.0      Москва ТЦ "МЕГА Белая Дача II"  iTunes 1500 руб.
# 1573253         502.0      Москва ТЦ "МЕГА Белая Дача II"  iTunes 1500 руб.
#
#          item_category_id                 item_category_name
# 807027                 32  Карты оплаты (Кино, Музыка, Игры)
# 1596496                32  Карты оплаты (Кино, Музыка, Игры)
# 1596497                32  Карты оплаты (Кино, Музыка, Игры)
# 1599851                32  Карты оплаты (Кино, Музыка, Игры)
# 1631422                32  Карты оплаты (Кино, Музыка, Игры)
# ...                   ...                                ...
# 2043157                32  Карты оплаты (Кино, Музыка, Игры)
# 1571406                32  Карты оплаты (Кино, Музыка, Игры)
# 1618930                32  Карты оплаты (Кино, Музыка, Игры)
# 1573252                32  Карты оплаты (Кино, Музыка, Игры)
# 1573253                32  Карты оплаты (Кино, Музыка, Игры)
#
# [258 rows x 10 columns]

# %% [markdown]
# Based on the section above, it item_cnd_day for 3731 and 8057 seem normal.

# %% [markdown]
# ## @AMY Maybe we can add new section here about doing the cleaning before proceed to data Analysis??

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# First we will need to add date related new columns for better analysis

# %%
normData['date_month'] = normData['date'].dt.month
normData['date_year'] = normData['date'].dt.year
#Calculate total normData
normData['total_sales'] =  normData['item_price'] * normData['item_cnt_day']

# %% [markdown]
# Prepare the sales year split by year for reusability

# %%
sales2013 = normData[normData['date_year'] == 2013]
sales2014 = normData[normData['date_year'] == 2014]
sales2015 = normData[normData['date_year'] == 2015]

# %% [markdown]
# ### 2.1 General Sales Trend

# %%
# Find aggregate sales by day
salesMonYea2013 = sales2013.groupby(['date_month','date_year'])[['total_sales']].agg('sum').reset_index()
salesMonYea2014 = sales2014.groupby(['date_month','date_year'])[['total_sales']].agg('sum').reset_index()
salesMonYea2015 = sales2015.groupby(['date_month','date_year'])[['total_sales']].agg('sum').reset_index()

totalSales = pd.concat([salesMonYea2013,salesMonYea2014,salesMonYea2015])

# %%
fig0,ax0=plt.subplots(figsize=(20,8));
sns.lineplot(x='date_month', y = 'total_sales', data = totalSales,
           hue='date_year', palette = 'Accent')

plt.title("Total Sales", fontsize = 20)
plt.xlabel("Month", fontsize = 15)
plt.ylabel("Total Sales", fontsize = 15)
legend = ax0.legend()
legend.texts[0].set_text("Year")
plt.show()

# %% [markdown]
# Let's look at the heatmap for sales trend

# %%
calHeatMap = normData[["date", "item_cnt_day"]]

calHeatMap.set_index("date", inplace = True)

calHeatMap = calHeatMap.resample("D")["item_cnt_day"].sum()

calmap.calendarplot(calHeatMap, # pass the series
                    fig_kws = {'figsize': (16,10)}, 
                    cmap='YlGn',
                    fillcolor='grey',
                    yearlabel_kws = {'color':'black', 'fontsize':14}, 
                    subplot_kws = {'title':'Total sales per year'}
                   );

# %% [markdown]
# Let's check item count trend as well

# %%
# Find aggregate sales by day
itemCntYea2013 = sales2013.groupby(['date_month','date_year'])[['item_cnt_day']].agg('sum').reset_index()
itemCntYea2014 = sales2014.groupby(['date_month','date_year'])[['item_cnt_day']].agg('sum').reset_index()
itemCntYea2015 = sales2015.groupby(['date_month','date_year'])[['item_cnt_day']].agg('sum').reset_index()

itemCntYea = pd.concat([itemCntYea2013,itemCntYea2014,itemCntYea2015])

# %%
fig0,ax0=plt.subplots(figsize=(20,8));
sns.lineplot(x='date_month', y = 'item_cnt_day', data = itemCntYea,
           hue='date_year', palette = 'Accent')

plt.title("Total Item Count", fontsize = 20)
plt.xlabel("Month", fontsize = 15)
plt.ylabel("Total Item Count", fontsize = 15)
legend = ax0.legend()
legend.texts[0].set_text("Year")
plt.show()

# %% [markdown]
# ### 2.2 Items

# %%
item_sales = normData.groupby(['item_id'])[['total_sales']].agg('sum').reset_index()

item_sales
# Out:
#        item_id  total_sales
# 0            0        58.00
# 1            1     26940.00
# 2            2       116.00
# 3            3       158.00
# 4            4        58.00
# ...        ...          ...
# 21801    22165       118.00
# 21802    22166     52200.00
# 21803    22167    393108.75
# 21804    22168      4793.50
# 21805    22169      4349.00
#
# [21806 rows x 2 columns]

# %% [markdown]
# Let's explore the graph for Top 10 Total Sales by Item

# %%
def buildItemSalesGraph(df,ax0,year):
    
    item_sales = df.groupby(['item_id'])[['total_sales']].agg('sum').reset_index()
    
    item_sales = item_sales.sort_values(by=['total_sales'], ascending =False)

    item_sales = item_sales.head(n = 10)
    
    axTotal= sns.barplot(ax=ax0, x = item_sales.item_id, 
                y = item_sales.total_sales,
               order= item_sales.sort_values('total_sales').item_id,
                color = 'lightsteelblue')
   
    if year == '':
        axTotal.title.set_text('Top 10 Item by Sales for All Years')
    else: 
        title = 'Top 10 Item by Sales ' + str(year)
        axTotal.title.set_text(title)
    
    axTotal.set_xlabel('Item ID')
    axTotal.set_ylabel('Total Sales')
    axTotal.yaxis.set_tick_params(labelbottom=True)
    
# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10), sharey=True)

buildItemSalesGraph(normData,axes[0,0],'')
buildItemSalesGraph(sales2013,axes[0,1],2013)
buildItemSalesGraph(sales2014,axes[1,0],2014)
buildItemSalesGraph(sales2015,axes[1,1],2015)

# %% [markdown]
# Let's explore the graph for Top 10 Total Sales by Item

# %%
def buildItemCntGraph(df,ax0,year):

    sales_item_cnt = df.groupby(['item_id'])[['item_cnt_day']].agg('sum').reset_index()

    sales_item_cnt = sales_item_cnt.sort_values(by=['item_cnt_day'], ascending =False)

    sales_item_cnt = sales_item_cnt.head(n = 10)

    ax= sns.barplot(ax=ax0, x = sales_item_cnt.item_id, 
                y = sales_item_cnt.item_cnt_day,
               order=sales_item_cnt.sort_values('item_cnt_day').item_id,
                   color = 'lightsteelblue')
    
    if year == '':
        ax.title.set_text('Top 10 Item by Count for All Years')
    else: 
        title = 'Top 10 Item by Count ' + str(year)
        ax.title.set_text(title)
    
    ax.set_xlabel('Item ID')
    ax.set_ylabel('Total Item Count')
    ax.yaxis.set_tick_params(labelbottom=True)
    
# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10), sharey=True)

buildItemCntGraph(normData,axes[0,0],'')
buildItemCntGraph(sales2013,axes[0,1],2013)
buildItemCntGraph(sales2014,axes[1,0],2014)
buildItemCntGraph(sales2015,axes[1,1],2015)

# %% [markdown]
# ### 2.3 Shop

# %%
# Checking Shop with top 10 Sales
# Prepare subplots
def buildShopSalesGraph(df,ax0,year):

    sales_shop = df.groupby(['shop_id'])[['total_sales']].agg('sum').reset_index()

    sales_shop = sales_shop.sort_values(by=['total_sales'], ascending =False)

    sales_shop = sales_shop.head(n = 10)

    ax= sns.barplot(ax=ax0, x = sales_shop.shop_id, 
                y = sales_shop.total_sales,
               order=sales_shop.sort_values('total_sales').shop_id,
                   color = 'lightsteelblue')
    
    if year == '':
        ax.title.set_text('Top 10 Shop by Sales for All Years')
    else: 
        title = 'Top 10 Shop by Sales ' + str(year)
        ax.title.set_text(title)
    
    ax.set_xlabel('Shop ID')
    ax.set_ylabel('Total Sales')
    ax.yaxis.set_tick_params(labelbottom=True)

# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10), sharey=True)

buildShopSalesGraph(normData,axes[0,0],'')
buildShopSalesGraph(sales2013,axes[0,1],2013)
buildShopSalesGraph(sales2014,axes[1,0],2014)
buildShopSalesGraph(sales2015,axes[1,1],2015)

# %%
# Checking Top 10 shop with Item count
# Prepare subplots
def buildShopCntGraph(df,ax0,year):

    sales_shop = df.groupby(['shop_id'])[['item_cnt_day']].agg('sum').reset_index()

    sales_shop = sales_shop.sort_values(by=['item_cnt_day'], ascending =False)

    sales_shop = sales_shop.head(n = 10)

    ax= sns.barplot(ax=ax0, x = sales_shop.shop_id, 
                y = sales_shop.item_cnt_day,
               order=sales_shop.sort_values('item_cnt_day').shop_id,
                   color = 'lightsteelblue')
    
    if year == '':
        ax.title.set_text('Top 10 Shop by Item Count for All Years')
    else: 
        title = 'Top 10 Shop by Item Count ' + str(year)
        ax.title.set_text(title)
    
    ax.set_xlabel('Shop ID')
    ax.set_ylabel('Item Count')
    ax.yaxis.set_tick_params(labelbottom=True)

# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10),sharey=True)

buildShopCntGraph(normData,axes[0,0],'')
buildShopCntGraph(sales2013,axes[0,1],2013)
buildShopCntGraph(sales2014,axes[1,0],2014)
buildShopCntGraph(sales2015,axes[1,1],2015)

# %% [markdown]
# ### 2.4 Categories

# %%
# Checking Top 10 shop with Item count
# Prepare subplots
def buildCatSalesGraph(df,ax0,year):

    sales_cat = df.groupby(['item_category_id'])[['total_sales']].agg('sum').reset_index()

    sales_cat = sales_cat.sort_values(by=['total_sales'], ascending =False)

    sales_cat = sales_cat.head(n = 10)

    ax= sns.barplot(ax=ax0, x = sales_cat.item_category_id, 
                y = sales_cat.total_sales,
               order=sales_cat.sort_values('total_sales').item_category_id,
                   color = 'lightsteelblue')
    
    if year == '':
        ax.title.set_text('Top 10 Categories by Item Count for All Years')
    else: 
        title = 'Top 10 Categories by Item Count ' + str(year)
        ax.title.set_text(title)
    
    ax.set_xlabel('Item Category')
    ax.set_ylabel('Total Sales')
    ax.yaxis.set_tick_params(labelbottom=True)

# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10),sharey=True)

buildCatSalesGraph(normData,axes[0,0],'')
buildCatSalesGraph(sales2013,axes[0,1],2013)
buildCatSalesGraph(sales2014,axes[1,0],2014)
buildCatSalesGraph(sales2015,axes[1,1],2015)

# %%
# Checking Top 10 shop with Item count
# Prepare subplots
def buildCatCntGraph(df,ax0,year):

    sales_cat = df.groupby(['item_category_id'])[['item_cnt_day']].agg('sum').reset_index()

    sales_cat = sales_cat.sort_values(by=['item_cnt_day'], ascending =False)

    sales_cat = sales_cat.head(n = 10)

    ax= sns.barplot(ax=ax0, x = sales_cat.item_category_id, 
                y = sales_cat.item_cnt_day,
               order=sales_cat.sort_values('item_cnt_day').item_category_id,
                   color = 'lightsteelblue')
    
    if year == '':
        ax.title.set_text('Top 10 Shop by Item Count for All Years')
    else: 
        title = 'Top 10 Shop by Item Count ' + str(year)
        ax.title.set_text(title)
    
    ax.set_xlabel('Item Category')
    ax.set_ylabel('Item Count')
    ax.yaxis.set_tick_params(labelbottom=True)

# Checking best item selling by sales - Top 10
# Prepare subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10),sharey=True)

buildCatCntGraph(normData,axes[0,0],'')
buildCatCntGraph(sales2013,axes[0,1],2013)
buildCatCntGraph(sales2014,axes[1,0],2014)
buildCatCntGraph(sales2015,axes[1,1],2015)
